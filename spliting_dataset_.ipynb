# %%
# Importing Necessary Libraries
import cv2
import os
import shutil
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
# Function for Creating Train / Validation / Test folders (One time use Only)

def TrainValTestSplit(root_dir, classes_dir, val_ratio = 0.15, test_ratio = 0.15):
    for cls in classes_dir:
        # Creating Split Folders
        os.makedirs(r'Oral_Cancer\train\\' + cls)
        os.makedirs(r'Oral_Cancer\val\\'  + cls)
        os.makedirs(r'Oral_Cancer\test\\' + cls)

        # Folder to copy images from
        src = root_dir +  cls

        # Storing the Filenames
        allFileNames = os.listdir(src)
        np.random.shuffle(allFileNames)
        # Spliting the Files in the Given ratio
        train_FileNames, val_FileNames, test_FileNames = np.split(np.array(allFileNames), [int(len(allFileNames)* (1 - (val_ratio + test_ratio))), int(len(allFileNames)* (1 - test_ratio))])

        train_FileNames = [src+'\\'+ name for name in train_FileNames.tolist()]
        val_FileNames = [src+'\\' + name for name in val_FileNames.tolist()]
        test_FileNames = [src+'\\' + name for name in test_FileNames.tolist()]

        # Printing the Split Details
        print(cls.upper(),':')
        print('Total images: ', len(allFileNames))
        print('Training: ', len(train_FileNames))
        print('Validation: ', len(val_FileNames))
        print('Testing: ', len(test_FileNames))

        # Copy-pasting images
        for name in train_FileNames:
            shutil.copy(name, 'train\\' + cls)

        for name in val_FileNames:
            shutil.copy(name, 'val\\' + cls)

        for name in test_FileNames:
            shutil.copy(name, 'test\\' + cls)
        print();

# Preforming Train / Validation / Test Split
root_dir = r'C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer'              # Dataset Root Folder
classes_dir = ['cancer', 'non_cancer']  # Classes
TrainValTestSplit(root_dir, classes_dir);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 44
#      42 root_dir = r'C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer'              # Dataset Root Folder
#      43 classes_dir = ['cancer', 'non_cancer']  # Classes
# ---> 44 TrainValTestSplit(root_dir, classes_dir)
#
# Cell In[21], line 14, in TrainValTestSplit(root_dir, classes_dir, val_ratio, test_ratio)
#      11 src = root_dir +  cls
#      13 # Storing the Filenames
# ---> 14 allFileNames = os.listdir(src)
#      15 np.random.shuffle(allFileNames)
#      16 # Spliting the Files in the Given ratio
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\user\\Documents\\Tazin\\Oral_Cancer\\Augmented_Oral_Cancercancer'

# %%
original_folder = r"C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer"
train_folder = r"C:\Users\user\Documents\Tazin\Oral_Cancer\Oral_Cancer\train"
test_folder = r"C:\Users\user\Documents\Tazin\Oral_Cancer\Oral_Cancer\test"
validate_folder = r"C:\Users\user\Documents\Tazin\Oral_Cancer\Oral_Cancer\validate"

# %%
os.mkdir(train_folder)
os.mkdir(test_folder)
os.mkdir(validate_folder)

# %%
Train_path= os.path.join(train_folder, "non_cancer")
Test_path= os.path.join(test_folder, "non_cancer")
Valid_path = os.path.join(validate_folder, "non_cancer")
os.mkdir(Train_path)
os.mkdir(Test_path)
os.mkdir(Valid_path)

# %%
Train_path= os.path.join(train_folder, "cancer")
Test_path= os.path.join(test_folder, "cancer")
Valid_path = os.path.join(validate_folder, "cancer")
os.mkdir(Train_path)
os.mkdir(Test_path)
os.mkdir(Valid_path)

# %%
import os

File_length=[]

dir_path = original_folder
path= "cancer"
Dir_path= os.path.join(dir_path, path)
count = 0
# Iterate directory
for path in os.listdir(Dir_path):
# check if current path is a file
    if os.path.isfile(os.path.join(Dir_path, path)):
        count += 1
print("cancer",count)
# Out:
# cancer 440

# %%
path= "non_cancer"
Dir_path= os.path.join(dir_path, path)
count = 0
# Iterate directory
for path in os.listdir(Dir_path):
# check if current path is a file
    if os.path.isfile(os.path.join(Dir_path, path)):
        count += 1
print("non_cancer",count)
# Out:
# non_cancer 449

# %%
import os
os.getcwd()
collection = r"C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer"
i=1
for path in os.listdir(collection):
    if os.path.isfile(os.path.join(collection, path)):
        prev=os.path.join(collection, path)
        path2="cancer_"+str(i)+".jpg"
        i=i+1
        #print(path2)
        curr=os.path.join(collection, path2)
        print(curr)
        os.rename(prev, curr)
#"E:\basic_characters\original\3\1_3.jpg"
#for i, filename in enumerate(os.listdir(collection)):
   # os.rename("E:\basic_characters\original\3" + filename, "E:\basic_characters\original\3\3_" + str(i) + ".jpg")
# Out:
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_1.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_2.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_3.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_4.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_5.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_6.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_7.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_8.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_9.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_10.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\cancer\cancer_11.jpg
# ...

# %%
import os
os.getcwd()
collection = r"C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer"
i=1
for path in os.listdir(collection):
    if os.path.isfile(os.path.join(collection, path)):
        prev=os.path.join(collection, path)
        path2="non_cancer_"+str(i)+".jpg"
        i=i+1
        #print(path2)
        curr=os.path.join(collection, path2)
        print(curr)
        os.rename(prev, curr)
#"E:\basic_characters\original\3\1_3.jpg"
#for i, filename in enumerate(os.listdir(collection)):
   # os.rename("E:\basic_characters\original\3" + filename, "E:\basic_characters\original\3\3_" + str(i) + ".jpg")
# Out:
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_1.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_2.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_3.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_4.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_5.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_6.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_7.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_8.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_9.jpg
# C:\Users\user\Documents\Tazin\Oral_Cancer\Augmented_Oral_Cancer\non_cancer\non_cancer_10.jpg
# ...

# %%
path= "non_cancer"
folder_name="non_cancer"
Dir_path= os.path.join(dir_path, path)
Train_path= os.path.join(train_folder, path)
Test_path= os.path.join(test_folder, path)
Valid_path= os.path.join(validate_folder, path)
#    Validate_path= os.path.join(validate_folder, path)
filenames=[f"{folder_name}_{i}.jpg" for i in range(1,315)]
for filename in filenames:
    src_path = os.path.join(Dir_path,filename)
    dst_path = os.path.join(Train_path,filename)
    #print(src_path+"                     "+dst_path)
    shutil.copy(src_path,dst_path)

# %%
path= "non_cancer"
folder_name="non_cancer"
Dir_path= os.path.join(dir_path, path)
Train_path= os.path.join(train_folder, path)
Test_path= os.path.join(test_folder, path)
Valid_path= os.path.join(validate_folder, path)
#    Validate_path= os.path.join(validate_folder, path)
filenames=[f"{folder_name}_{i}.jpg" for i in range(315,382)]
for filename in filenames:
    src_path = os.path.join(Dir_path,filename)
    dst_path = os.path.join(Valid_path,filename)
    shutil.copy(src_path,dst_path)

# %%
path= "non_cancer"
folder_name="non_cancer"
Dir_path= os.path.join(dir_path, path)
Train_path= os.path.join(train_folder, path)
Test_path= os.path.join(test_folder, path)
Valid_path= os.path.join(validate_folder, path)
#    Validate_path= os.path.join(validate_folder, path)
filenames=[f"{folder_name}_{i}.jpg" for i in range(382,450)]
for filename in filenames:
    src_path = os.path.join(Dir_path,filename)
    dst_path = os.path.join(Test_path,filename)
    shutil.copy(src_path,dst_path)

# %%
path= "cancer"
folder_name="cancer"
Dir_path= os.path.join(dir_path, path)
Train_path= os.path.join(train_folder, path)
Test_path= os.path.join(test_folder, path)
Valid_path= os.path.join(validate_folder, path)
#    Validate_path= os.path.join(validate_folder, path)
filenames=[f"{folder_name}_{i}.jpg" for i in range(1,309)]
for filename in filenames:
    src_path = os.path.join(Dir_path,filename)
    dst_path = os.path.join(Train_path,filename)
    shutil.copy(src_path,dst_path)

# %%
path= "cancer"
folder_name="cancer"
Dir_path= os.path.join(dir_path, path)
Train_path= os.path.join(train_folder, path)
Test_path= os.path.join(test_folder, path)
Valid_path= os.path.join(validate_folder, path)
#    Validate_path= os.path.join(validate_folder, path)
filenames=[f"{folder_name}_{i}.jpg" for i in range(309,375)]
for filename in filenames:
    src_path = os.path.join(Dir_path,filename)
    dst_path = os.path.join(Valid_path,filename)
    shutil.copy(src_path,dst_path)

# %%
path= "cancer"
folder_name="cancer"
Dir_path= os.path.join(dir_path, path)
Train_path= os.path.join(train_folder, path)
Test_path= os.path.join(test_folder, path)
Valid_path= os.path.join(validate_folder, path)
#    Validate_path= os.path.join(validate_folder, path)
filenames=[f"{folder_name}_{i}.jpg" for i in range(375,441)]
for filename in filenames:
    src_path = os.path.join(Dir_path,filename)
    dst_path = os.path.join(Test_path,filename)
    shutil.copy(src_path,dst_path)
